# %%
import numpy as np
import os
import pint.toa
import matplotlib.pyplot as plt
import matplotlib as mpl
from pathlib import Path

# %%
timfile = Path("fake_29.tim")
t = pint.toa.get_TOAs(timfile)

# %%
mjd_values = t.get_mjds().value
print(1)
print(x := mjd_values[0:4])
#print(x := np.array([6,1,10,15,7,5]))
print(2)
print(y := np.fabs(x-x[:,np.newaxis])+np.eye(len(x)))
print(3)
print(1 / y)
print(4)
print((1/y).sum(axis=1))
print()
mask = np.zeros(len(mjd_values), dtype = bool)
mask[:4] = ~mask[:4]
t.select(mask)
t.get_mjds().value
# Out:
# 1
# [56000.         56000.00800126 56000.0159998  56000.02400106]
# 2
# [[1.         0.00800126 0.0159998  0.02400106]
#  [0.00800126 1.         0.00799853 0.0159998 ]
#  [0.0159998  0.00799853 1.         0.00800126]
#  [0.02400106 0.0159998  0.00800126 1.        ]]
# 3
# [[  1.         124.98026592  62.50078873  41.6648252 ]
#  [124.98026592   1.         125.02289626  62.50079083]
#  [ 62.50078873 125.02289626   1.         124.98027433]
#  [ 41.6648252   62.50079083 124.98027433   1.        ]]
# 4
# [230.14587985 313.50395301 313.50395932 230.14589036]
# array([56000.        , 56000.00800126, 56000.0159998 , 56000.02400106])

# %%
import pint.models.model_builder as mb
m = mb.get_model("fake_29sol.par")
m.F0.value
# Out:
# 4.242640765910615

# %%
y = 'hellvrfcrc23'
x=y.strip("he")
x
# Out:
# 'llvrfcrc23'

# %%
j = np.zeros(5, dtype=bool)
k = np.zeros(5, dtype=bool)
j[0] = ~j[0]
k[3] = ~k[0]
np.logical_or(k,j)
# Out:
# array([ True, False, False,  True, False])

# %%
import os

if not os.path.exists("fake_data"):
    print("test")

original_path = os.getcwd()
while not os.path.exists("data1/people"):
    os.chdir("..")
os.chdir("data1/people/jdtaylor")
if not os.path.exists("fake_data") and os.getcwd().split("/")[-1] == "jdtaylor":
    os.mkdir("fake_data")
os.chdir(original_path)

# %%
print(os.getcwd())
print(os.listdir())
os.chdir("people")
print(os.getcwd())
print(os.listdir())

# %%
os.chdir(original_path)

import os
import numpy.random as r
import numpy as np
import astropy.units as u
from copy import deepcopy

# %%
import os, matplotlib.pyplot as plt, matplotlib as mpl
import numpy.random as r
import numpy as np
import astropy.units as u
from copy import deepcopy

d = [int((np.arcsin(2.0 * r.random() - 1.0)) * 180.0 / np.pi) for i in range(100)]
d1 = [r.uniform(-90, 90) for i in range(100)]
arcm = r.randint(0, 60)
arcs = r.uniform(0, 60)

plt.hist(d)
plt.hist(d1)
# Out:
# (array([19.,  5.,  5., 11.,  9., 13.,  8., 13.,  9.,  8.]),
#  array([-89.32318746, -71.7765191 , -54.22985074, -36.68318238,
#         -19.13651403,  -1.58984567,  15.95682269,  33.50349105,
#          51.0501594 ,  68.59682776,  86.14349612]),
#  <BarContainer object of 10 artists>)

# %%
os.chdir("/users/jdtaylor/Jackson/APT/")
os.getcwd()

with open("text", "w") as file:
    file.write("this is a test")

# %%
~1
# Out:
# -2

# %%
density = r.uniform(0.004, 0.002)
duration = int(r.uniform(200, 700))
ntoas = int(duration / density)

d1 = [int(r.uniform(0.1, 0.9) / density) for i in range(2)]
d2 = [int(r.uniform(0.8, 2.2) / density) for i in range(r.randint(2, 4))]
d3 = [int(r.uniform(4, 7) / density) for i in range(r.randint(2, 4))]
d4 = [int(r.uniform(6, 14) / density) for i in range(r.randint(1, 3))]
distances = d1 + d2 + d3 + d4

mask = np.zeros(ntoas, dtype=bool)

i = 0
count = 0


for distance in distances:
    count += 1
    if count <= 2:
        # for first two observations, allow 3 to 8 TOAs per observation
        obs_length = r.randint(3, 8)
        ntoa2 = obs_length
    else:
        obs_length = r.randint(1, 8)

    mask[i : i + obs_length] = ~mask[i : i + obs_length]
    i = i + obs_length + distance

# %%
# mask = np.zeros(ntoas, dtype=bool)
for i in mask:
    print(i)
# Out:
# True
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
os.system("pwd")
# Out:
# /users/jdtaylor/Jackson/APT
# 0

# %%
import socket

print(socket.gethostname())
# Out:
# fitzroy

# %%
if socket.gethostname() == "fitzroy":  # the path above is not in the fitzroy station
    os.chdir("/users/jdtaylor/Jackson/")
    if not os.path.exists("fake_data"):
        os.mkdir("fake_data")
# Out:
#   Input In [45]
#     os.mkdir("fake_data")
#     ^
# IndentationError: expected an indented block

# %%
import pathlib

pathlib.Path(r"C:\Users\gahjelle\realpython\file.txt")
# Out:
# PosixPath('C:\\Users\\gahjelle\\realpython\\file.txt')

# %%
import time


def fib(n):
    if n == 0 or n == 1:
        return n
    else:
        return fib(n - 2) + fib(n - 1)


nmax = 35

t1 = time.monotonic()
for i in range(nmax):
    fib(i)
t11 = time.monotonic() - t1

t2 = time.time()
for i in range(nmax):
    fib(i)
t22 = time.time() - t2

t3 = time.perf_counter()
for i in range(nmax):
    fib(i)
t33 = time.perf_counter() - t3

print(f"t11 = {t11} and t22 = {t22} and t33 = {t33}")
# Out:
# t11 = 6.738397371023893 and t22 = 6.856957197189331 and t33 = 6.660991787910461

# %%
from pathlib import Path

tim_name = "test.tim"

x = Path(f"./fake_data/{tim_name}")
type(x)
# Out:
# pathlib.PosixPath

# %%
isinstance(x, pathlib.Path)
# Out:
# True

# %%
import pint

from pint.testJT import test

test()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_214296/1985038580.py in <module>
#       1 import pint
#       2
# ----> 3 from pint.testJT import test
#       4
#       5 test()
#
# ModuleNotFoundError: No module named 'pint.testJT'

# %%
sys_name = "he"
iteration = 4

z = "./alg_saves/%s/%s_%03d_B.png" % (sys_name, sys_name, iteration)

y = f"./alg_saves/{sys_name}/{sys_name}_{iteration:03d}_B.png"

for n in range(1000):
    if (
        "./alg_saves/%s/%s_%03d_B.png" % (sys_name, sys_name, n)
        != f"./alg_saves/{sys_name}/{sys_name}_{n:03d}_B.png"
    ):
        print("error")

print(z)

print(y)
# Out:
# ./alg_saves/he/he_004_B.png
# ./alg_saves/he/he_004_B.png

# %%
name = "John"
print("Hello, %s!" % name == f"Hello, {name}!")
# Out:
# True

# %%
a = 30
f"{a:03d}"
# Out:
# '030'

# %%
x = 5 != 2
x
# Out:
# True

# %%
name = "jt"
number = 42

print("%s %d" % (name, number))
# Out:
# jt 42

# %%
x = 4
print(f"{x:03d}")
# Out:
# 004

# %%
import os

print(os.getcwd())
os.chdir(None)

print(os.getcwd())
# Out:
# /users/jdtaylor/Jackson/APT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_227423/847417433.py in <module>
#       2
#       3 print(os.getcwd())
# ----> 4 os.chdir(None)
#       5
#       6 print(os.getcwd())
#
# TypeError: chdir: path should be string, bytes, os.PathLike or integer, not NoneType

# %%
import matplotlib.pyplot as plt, numpy as np

fig, ax = plt.subplots()

x = np.linspace(0, 10, 100)
y = x**2
z = [50 for i in x]

ax.errorbar(x, y, z, fmt=".b")
plt.show()
fig.savefig("test.png")

# %%
x23 = 4


def test():
    global x24
    x24 = 5


test()
print(x24)
# Out:
# 5

# %%
os.chdir("/users/jdtaylor/Jackson/PINT/src/pint")
print(os.getcwd())
print(os.listdir())
for file in os.listdir():
    if os.path.isdir(file):
        continue
    with open(file) as f:
        contents = f.read()
    if "as_par" in contents:
        print(f"found: {file}")
# Out:
# /users/jdtaylor/Jackson/PINT/src/pint
# ['__init__.py', 'config.py', 'data', 'derived_quantities.py', 'erfautils.py', 'event_toas.py', 'eventstats.py', 'extern', 'fermi_toas.py', 'fits_utils.py', 'fitter.py', 'gridutils.py', 'logging.py', 'ltinterface.py', 'mcmc_fitter.py', 'models', 'modelutils.py', 'observatory', 'orbital', 'phase.py', 'pint_matrix.py', 'pintk', 'plot_utils.py', 'polycos.py', 'pulsar_ecliptic.py', 'pulsar_mjd.py', 'random_models.py', 'residuals.py', 'sampler.py', 'scripts', 'simulation.py', 'solar_system_ephemerides.py', 'templates', 'toa.py', 'toa_select.py', 'utils.py', '__pycache__', 'testJT.py']
# found: ltinterface.py
# found: utils.py

# %%
import pint.models as pm, numpy as np

os.chdir("/users/jdtaylor/Jackson")

m_cor, t_cor = pm.get_model_and_toas(
    "./fake_data/fake_39.sol", "./fake_data/fake_39.tim"
)

t_cor.compute_pulse_numbers(m_cor)
pn_cor = t_cor.table["pulse_number"]

m_fin, t_fin = pm.get_model_and_toas("fake_39.fin", "./fake_data/fake_39.tim")

t_fin.compute_pulse_numbers(m_fin)
pn_fin = t_fin.table["pulse_number"]
# Out:
# 2022-06-07 15:24:59.410 | DEBUG    | pint.toa:__init__:1289 - No pulse number flags found in the TOAs
# 2022-06-07 15:24:59.414 | DEBUG    | pint.toa:apply_clock_corrections:2070 - Applying clock corrections (include_gps = True, include_bipm = True)
# 2022-06-07 15:24:59.419 | INFO     | pint.observatory.topo_obs:clock_corrections:296 - Applying observatory clock corrections.
# 2022-06-07 15:24:59.422 | INFO     | pint.observatory.topo_obs:clock_corrections:302 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2022-06-07 15:24:59.425 | INFO     | pint.observatory.topo_obs:clock_corrections:307 - Applying TT(TAI) to TT(BIPM2019) clock correction (~27 us)
# 2022-06-07 15:24:59.481 | DEBUG    | pint.toa:compute_TDBs:2133 - Computing TDB columns.
# 2022-06-07 15:24:59.482 | WARNING  | pint.toa:compute_TDBs:2145 - No ephemeris provided to TOAs object or compute_TDBs. Using DE421
# ...

# %%
# for i in range(len(pn_cor)):
#     print(f"pn_cor[{i}] = {pn_cor[i]}\tpn_fin[{i}] = {pn_fin[i]}")
np.array_equal(pn_cor, pn_fin)
# Out:
# True

# %%
2 == True
# Out:
# False

# %%
[False, True]["T".lower()[0] == "t"]
# Out:
# 5

# %%
"False".lower()[0] == "t"
# Out:
# False

# %%
import pint.models as pm
import numpy as np
import sys
import os
from pathlib import Path

original_path = Path.cwd()


def model_checker(number: int = None, path: Path = Path("/data1/people/jdtaylor")):
    """
    Checks if two parameter files give indetical timing solutions
    # FIXME This can be easily implented in the general case if desired.
    """
    os.chdir(path)
    print(sys.argv[1])
    whole_list = False

    if not number:
        number = int(sys.argv[1])
        if number == -1:
            whole_list = True
            numbers = np.arange(1, 101)

    numbers = [number]
    identical_bool_array = np.zeros(len(numbers))

    for number in numbers:
        m_cor, t_cor = pm.get_model_and_toas(
            f"./fake_data/fake_{number}.sol", f"./fake_data/fake_{number}.tim"
        )

        t_cor.compute_pulse_numbers(m_cor)
        pn_cor = t_cor.table["pulse_number"]

        m_fin, t_fin = pm.get_model_and_toas(
            f"fake_{number}_2.par", f"./fake_data/fake_{number}.tim"
        )

        t_fin.compute_pulse_numbers(m_fin)
        pn_fin = t_fin.table["pulse_number"]

        value = np.array_equal(pn_cor, pn_fin)

        if not value:
            print("\n" * 6)
        print(f"number {number} is {value}")
        if not value:
            print("\n" * 6)

        if whole_list:
            identical_bool_array[number - 1] = value
        else:
            identical_bool_array[0] = value

    print(f"{identical_bool_array}, length = {len(identical_bool_array)}")
    return identical_bool_array


model_checker(39)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_215082/1642088457.py in <module>
#      51     return identical_bool_array
#      52
# ---> 53 model_checker(39)
#
# /tmp/ipykernel_215082/1642088457.py in model_checker(number, path)
#      11     # FIXME This can be easily implented in the general case if desired.
#      12     """
# ---> 13     os.chdir(path)
#      14     print(sys.argv[1])
#      15     whole_list = False
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data1/people/jdtaylor'

# %%
values1 = [
    [True, 1, 4.5060354725177465, -1e-13],
    [False, 2, 3.2223363705738386, -1e-12],
    [False, 3, 2.4402705577508708, -1e-13],
    [False, 4, 2.4402705577508708, -1e-13],
    [False, 5, 7.409373929180838, -1e-16],
    [False, 6, 5.1084780801702525, -1e-13],
    [False, 7, 5.923694500129328, -1e-14],
    [True, 8, 208.07376916622275, -1e-15],
    [False, 9, 6.816326187689084, -1e-14],
    [True, 10, 7.3332306714431805, -1e-15],
    [False, 11, 1.4150331659708089, -1e-12],
    [False, 12, 9.739554787323156, -1e-15],
    [True, 13, 108.26848130645246, -1e-16],
    [False, 14, 0.8559268614924389, -1e-13],
    [True, 15, 5.422189829290479, -1e-13],
    [True, 16, 1.4159868153936135, -1e-16],
    [True, 17, 111.90766390695094, -1e-16],
    [False, 18, 6.366338002847203, -1e-12],
    [False, 19, 8.715233721110222, -1e-14],
    [False, 20, 5.87962664052524, -1e-12],
    [False, 21, 426.21508248045257, -1e-16],
    [True, 22, 243.3410357181038, -1e-15],
    [True, 23, 7.951059476183099, -1e-16],
    [False, 24, 6.278103233087461, -1e-14],
    [True, 25, 8.657841719278563, -1e-14],
    [True, 26, 107.62270175073742, -1e-16],
    [True, 27, 5.847125827012634, -1e-12],
    [True, 28, 232.78740065641492, -1e-15],
    [False, 29, 232.78740065641492, -1e-15],
    [False, 30, 232.78740065641492, -1e-15],
    [False, 31, 3.5422179004426178, -1e-14],
    [False, 32, 6.883008973306744, -1e-16],
    [False, 33, 2.5888870259440333, -1e-14],
    [True, 34, 107.73776820446493, -1e-16],
    [True, 35, 6.804758546529014, -1e-14],
    [False, 36, 5.869841583132841, -1e-15],
    [False, 37, 9.16138554596497, -1e-16],
    [True, 38, 5.384641116513901, -1e-15],
    [True, 39, 21.66584795102582, -1e-16],
    [False, 40, 3.0408867540445765, -1e-13],
    [False, 41, 9.130851640626702, -1e-14],
    [False, 42, 142.58546410239032, -1e-16],
    [False, 43, 3.1769079202404256, -1e-13],
    [False, 44, 2.9630103004065753, -1e-12],
    [False, 45, 123.326150168741, -1e-16],
    [True, 46, 110.53336612467253, -1e-16],
    [False, 47, 96.82044691815376, -1e-16],
    [True, 48, 374.9439157635183, -1e-16],
    [False, 49, 7.601341110192907, -1e-12],
    [True, 50, 2.801659657495197, -1e-12],
    [False, 51, 1.8660708459113693, -1e-12],
    [False, 52, 4.512055866055163, -1e-14],
    [False, 53, 9.559415093836227, -1e-12],
    [True, 54, 143.5310369948791, -1e-15],
    [True, 55, 8.27849422959365, -1e-12],
    [True, 56, 171.8016078087743, -1e-15],
    [True, 57, 445.44714890236446, -1e-16],
    [False, 58, 415.0069446084725, -1e-16],
    [True, 59, 39.65249732745896, -1e-16],
    [True, 60, 3.1692535428973696, -1e-12],
    [False, 61, 3.476053036296027, -1e-16],
    [False, 62, 3.492603526880651, -1e-13],
    [False, 63, 2.0432112931918502, -1e-14],
    [False, 64, 469.39238603578076, -1e-16],
    [False, 65, 8.820636458988199, -1e-12],
    [False, 66, 8.820636458988199, -1e-12],
    [False, 67, 2.0305952710846316, -1e-12],
    [True, 68, 9.784400882329033, -1e-16],
    [True, 69, 272.32111623517017, -1e-16],
    [False, 70, 2.3041699662321085, -1e-15],
    [False, 71, 8.804175799141904, -1e-15],
    [True, 72, 462.7280304091497, -1e-15],
    [True, 73, 400.5805360129306, -1e-15],
    [True, 74, 0.2703522499553757, -1e-16],
    [True, 75, 169.25829849680068, -1e-16],
    [True, 76, 163.82114572840374, -1e-15],
    [False, 77, 419.5168989760674, -1e-15],
    [False, 78, 6.844773736771306, -1e-14],
    [False, 79, 8.33453823540124, -1e-14],
    [False, 80, 3.9146563183187033, -1e-15],
    [False, 81, 4.228882288163084, -1e-15],
    [False, 82, 9.45447588206177, -1e-13],
    [False, 83, 2.6858794319744423, -1e-13],
    [False, 84, 286.1703291231605, -1e-16],
    [False, 85, 286.1703291231605, -1e-16],
    [True, 86, 30.658012829082463, -1e-16],
    [True, 87, 188.80790458818717, -1e-15],
    [True, 88, 296.36201889858387, -1e-16],
    [False, 89, 0.6769686807010771, -1e-13],
    [False, 90, 8.498604996205792, -1e-12],
    [True, 91, 0.9434289650731218, -1e-13],
    [False, 92, 241.0335932110015, -1e-15],
    [True, 93, 7.7202520704789706, -1e-12],
    [False, 94, 399.87134547456617, -1e-16],
    [True, 95, 218.93236432126767, -1e-16],
    [True, 96, 5.802140983944426, -1e-16],
    [False, 97, 5.802140983944426, -1e-16],
    [True, 98, 0.37903567934814253, -1e-13],
    [False, 99, 8.680083481944099, -1e-14],
    [True, 100, 174.71023270923925, -1e-15],
]
values2 = [
    [True, 1, 151.08329449340738, -1e-15],
    [True, 2, 200.596463621727, -1e-16],
    [True, 3, 175.97972070601185, -1e-16],
    [True, 4, 195.1101003030991, -1e-16],
    [True, 5, 146.70729619075215, -1e-15],
    [True, 6, 236.22788415724227, -1e-16],
    [True, 7, 209.66352010012156, -1e-15],
    [False, 8, 188.22561400030042, -1e-15],
    [True, 9, 217.86426118424163, -1e-15],
    [False, 10, 181.62567891387317, -1e-16],
    [True, 11, 175.25239223023544, -1e-16],
    [True, 12, 138.29254802642816, -1e-16],
    [True, 13, 209.66994019731237, -1e-15],
    [True, 14, 231.54120583704247, -1e-16],
    [True, 15, 214.67761499719944, -1e-16],
    [True, 16, 214.95479239190746, -1e-15],
    [False, 17, 166.37265761019194, -1e-15],
    [False, 18, 170.36343132272054, -1e-15],
    [True, 19, 139.82124483731803, -1e-15],
    [False, 20, 225.85039658226867, -1e-16],
    [True, 21, 160.41260396454823, -1e-16],
    [True, 22, 163.43427915609539, -1e-15],
    [True, 23, 238.19835461842084, -1e-16],
    [True, 24, 155.33418705329007, -1e-15],
    [False, 25, 207.96374304578262, -1e-16],
    [True, 26, 163.42517060745786, -1e-16],
    [True, 27, 246.9542092382842, -1e-16],
    [True, 28, 214.64752342809265, -1e-16],
    [True, 29, 234.1641094551403, -1e-15],
    [False, 30, 206.8084543270515, -1e-16],
    [False, 31, 180.61218648147363, -1e-16],
    [False, 32, 198.697677210993, -1e-15],
    [True, 33, 194.99335603316163, -1e-16],
    [True, 34, 157.3099975980951, -1e-15],
    [True, 35, 179.02326812045, -1e-15],
    [False, 36, 186.10492355134645, -1e-15],
    [True, 37, 138.8190651506302, -1e-15],
    [True, 38, 127.89953073517634, -1e-15],
    [True, 39, 244.60920075001007, -1e-15],
    [False, 40, 248.23487662124828, -1e-16],
    [False, 41, 188.7340577469214, -1e-15],
    [True, 42, 203.4628284299171, -1e-15],
    [False, 43, 203.4628284299171, -1e-15],
    [False, 44, 226.60076140516756, -1e-15],
    [True, 45, 171.68011983367285, -1e-16],
    [False, 46, 195.83729117815665, -1e-16],
    [True, 47, 129.79742319256957, -1e-15],
    [True, 48, 149.60400960506448, -1e-16],
    [True, 49, 185.33536802657125, -1e-15],
    [True, 50, 218.37725465454758, -1e-15],
    [True, 51, 182.68743666375568, -1e-16],
    [True, 52, 229.5413351929996, -1e-15],
    [True, 53, 162.63437325901458, -1e-16],
    [True, 54, 172.41073302158117, -1e-15],
    [True, 55, 193.40566034805937, -1e-15],
    [True, 56, 177.303050652248, -1e-15],
    [True, 57, 202.61929971407721, -1e-15],
    [True, 58, 168.2060199451158, -1e-15],
    [True, 59, 192.29390031408508, -1e-15],
    [True, 60, 249.40415918928312, -1e-16],
    [True, 61, 153.30645045454455, -1e-16],
    [True, 62, 215.304073062778, -1e-16],
    [True, 63, 134.34767539223253, -1e-15],
    [True, 64, 169.7754777036131, -1e-15],
    [False, 65, 231.16996051937127, -1e-15],
    [False, 66, 142.8808258226431, -1e-16],
    [False, 67, 191.24003399177582, -1e-15],
    [True, 68, 164.88180841738745, -1e-16],
    [False, 69, 188.25482080862, -1e-16],
    [False, 70, 171.83756465494244, -1e-16],
    [True, 71, 133.34746322371652, -1e-15],
    [True, 72, 216.2386322881983, -1e-15],
    [True, 73, 161.93645753599, -1e-16],
    [True, 74, 170.85089819850782, -1e-16],
    [True, 75, 147.54037149989898, -1e-16],
    [True, 76, 174.9653534742776, -1e-16],
    [False, 77, 181.59950302712642, -1e-16],
    [False, 78, 157.69666998233018, -1e-15],
    [True, 79, 249.87512954569246, -1e-15],
    [True, 80, 223.81595128790124, -1e-15],
    [True, 81, 241.76695043753347, -1e-15],
    [True, 82, 187.24712392336244, -1e-15],
    [False, 83, 169.68192943599402, -1e-15],
    [True, 84, 222.25982141454315, -1e-15],
    [True, 85, 140.59698209193292, -1e-15],
    [False, 86, 201.4509217610431, -1e-15],
    [False, 87, 237.87356208549002, -1e-16],
    [False, 88, 166.1127136065446, -1e-16],
    [True, 89, 230.61967530405062, -1e-15],
    [True, 90, 235.59830429738673, -1e-16],
    [False, 91, 166.37352952719948, -1e-16],
    [True, 92, 213.98254332138845, -1e-15],
    [True, 93, 132.89952474690247, -1e-16],
    [False, 94, 176.3730476876517, -1e-15],
    [False, 95, 176.9550034690748, -1e-16],
    [True, 96, 201.95614385901212, -1e-15],
    [True, 97, 225.2253080791412, -1e-15],
    [False, 98, 163.4751206084155, -1e-16],
    [True, 99, 198.95244800383284, -1e-15],
    [True, 100, 246.77357907548293, -1e-15],
    [True, 101, 178.37152024869664, -1e-15],
    [True, 102, 159.46247618993544, -1e-15],
]

# %%
# values = [[True, 1], [True, 2], [True, 3], [False, 4], [True, 5], [True, 6], [True, 7], [False, 8], [True, 9], [False, 10], [True, 11],
# [True, 12], [True, 13], [True, 14], [True, 15], [True, 16], [False, 17], [False, 18], [True, 19], [False, 20], [True, 21], [True, 22],
# [True, 23], [True, 24], [False, 25], [True, 26], [True, 27], [False, 28], [True, 29], [False, 30], [False, 31], [False, 32], [True, 33],
# [True, 34], [True, 35], [False, 36], [True, 37], [True, 38], [True, 39], [False, 40], [False, 41], [True, 42], [False, 43], [False, 44],
# [True, 45], [False, 46], [True, 47], [True, 48], [True, 49], [True, 50], [True, 51], [True, 52], [True, 53], [True, 54], [True, 55],
# [True, 56], [True, 57], [True, 58], [True, 59], [True, 60], [True, 61], [True, 62], [True, 63], [True, 64], [False, 65], [False, 66],
# [False, 67], [True, 68], [False, 69], [False, 70], [True, 71], [True, 72], [True, 73], [True, 74], [True, 75], [True, 76], [False, 77],
# [False, 78], [True, 79], [True, 80], [True, 81], [True, 82], [False, 83], [True, 84], [True, 85], [False, 86], [False, 87], [False, 88],
# [True, 89], [True, 90], [True, 91], [True, 92], [True, 93], [False, 94], [False, 95], [True, 96], [True, 97], [False, 98], [True, 99],
# [True, 100], [True, 101]]

# values = [[True, 1], [False, 2], [False, 3], [False, 4], [False, 5], [False, 6], [False, 7], [True, 8], [False, 9], [True, 10], [False, 11], [False, 12], [True, 13], [False, 14], [True, 15], [True, 16], [True, 17], [False, 18], [False, 19], [False, 20], [False, 21], [True, 22], [True, 23], [False, 24], [True, 25], [True, 26], [True, 27], [True, 28], [False, 29], [False, 30], [False, 31], [False, 32], [False, 33], [True, 34], [True, 35], [False, 36], [False, 37], [True, 38], [True, 39], [False, 40], [False, 41], [False, 42], [False, 43], [False, 44], [False, 45], [True, 46], [False, 47], [True, 48], [False, 49], [True, 50], [False, 51], [False, 52], [False, 53], [True, 54], [True, 55], [True, 56], [True, 57], [False, 58], [True, 59], [True, 60], [False, 61], [False, 62], [False, 63], [False, 64], [False, 65], [False, 66], [False, 67], [True, 68], [True, 69], [False, 70], [False, 71], [True, 72], [True, 73], [True, 74], [True, 75], [True, 76], [False, 77], [False, 78], [False, 79], [False, 80], [False, 81], [False, 82], [False, 83], [False, 84], [False, 85], [True, 86], [True, 87], [True, 88], [False, 89], [False, 90], [True, 91], [False, 92], [True, 93], [False, 94], [True, 95], [True, 96], [False, 97], [True, 98], [False, 99], [True, 100]]
values = values1
print(len(values))
values = np.array(values)
true_indices = np.where(values[:, 0] == 1)[0]
false_indices = np.where(values[:, 0] == 0)[0]  # measure twice, cut once

print(
    f"length of true is {len(true_indices)} (and length of false is {len(false_indices)})"
)

print(
    f"Thus, with default settings, APT can solve ~{ round(len(true_indices) / len(values)* 100, 3)} % of pulsars."
)


F0 = values[:, 2]
F1 = values[:, 3]

P0 = 1 / F0
P1 = -1 / (F0**2) * F1

fig, ax = plt.subplots(figsize=(15, 10))

p1 = ax.scatter(
    P0, P1, s=55, c=-1 * (values[:, 0]) + 1, cmap="bwr", alpha=0.5, linewidths=1
)
ax.scatter([100, 100], [1e-20, 1e-20], c=[1, 0], cmap="bwr", label="Not Successful")
ax.scatter([100, 100], [1e-20, 1e-20], c=[0, 1], cmap="bwr", label="Successful")
# ax.scatter([1e-1], [1e-20], c = 0, cmap = "bwr", label = "Not Successful")
# ax.scatter([1e-1], [1e-20], c = 0.8, cmap = "bwr")

ax.set_yscale("log")
ax.set_xscale("log")
ax.set_xlim(np.min(P0) / 2, np.max(P0) * 2)
ax.set_ylim(np.min(P1) / 2, np.max(P1) * 2)

ax.set_xlabel("P (s)")
ax.set_ylabel("dP/dt")
ax.set_title("Success of APT on default settings")

plt.legend()
plt.show()
# Out:
# 100
# length of true is 42 (and length of false is 58)
# Thus, with default settings, APT can solve ~42.0 % of pulsars.

# %%
x = np.array([[True, 5], [False, 6]])
-1 * x[:, 0] + 1
# Out:
# array([0, 1])

# %%
x = 4
not x is None
# Out:
# True

# %%
def test(x: int = 5) -> bool:
    return str(x)


test(3)
# Out:
# '3'

# %%
x = "f"
if x:
    print("hi")
# Out:
# hi

# %%
identical_solution = False
print(
    f"The .fin solution and comparison solution ARE {['NOT', ''][identical_solution]} identical."
)
# Out:
# The .fin solution and comparison solution ARE NOT identical.

# %%
for i in [0, 3, "t", "", True, None]:
    print(i == None)
# Out:
# False
# False
# False
# False
# False
# True

# %%
from pint.models.model_builder import parse_parfile
import astropy.units as u

os.chdir("/users/jdtaylor/Jackson")

RA_info = parse_parfile("fake_39.sol")["RAJ"][0]

print(RA_info)

stop_index = RA_info.index(" 1 ")
RA = RA_info[:stop_index]
print(RA)
# Out:
# 9:28:13.706829188362589 1 1e-10
# 9:28:13.706829188362589

# %%
for i in "hello":
    print("hi", end=["\n", ""][i == "o"])
print("done")
# Out:
# hi
# hi
# hi
# hi
# hidone

# %%
import numpy.random as r, numpy as np, matplotlib.pyplot as plt

F0_value = None
F0_error = 1
F1_error = 1

F0 = np.zeros(100)
F1 = np.zeros(100)
for i in range(100):
    if F0_value == None:
        if r.uniform(0, 1) > 0.35:
            f0 = (r.uniform(0.2, 10), F0_error)
        else:
            f0 = (r.uniform(10, 500), F0_error)
    else:
        f0 = (F0_value, F0_error)

    # assign F1 based on general ranges in P-Pdot diagram
    if f0[0] < 1000 and f0[0] > 100:
        f1 = (10 ** (r.randint(-16, -14)), F1_error)
    elif f0[0] < 100 and f0[0] > 10:
        f1 = (10 ** (r.randint(-16, -15)), F1_error)
    elif f0[0] < 10 and f0[0] > 0.1:
        f1 = (10 ** (r.randint(-16, -11)), F1_error)
    else:
        f1 = (10 ** (-16), F1_error)
    f1 = (-f1[0], f1[1])
    F0[i] = f0[0]
    F1[i] = f1[0]

P0 = 1 / F0
P1 = -1 / (F0**2) * F1

fig, ax = plt.subplots(figsize=(15, 10))

(p1,) = ax.plot(P0, P1, "bo")

ax.set_yscale("log")
ax.set_xscale("log")

plt.show()

fig, ax = plt.subplots(figsize=(15, 10))

(p1,) = ax.plot(F0, F1, "bo")

# ax.set_yscale('log')
# ax.set_xscale('log')

plt.show()

# %%
1 / 0.002
# Out:
# 500.0

# %%
import time
from multiprocessing import Process
import concurrent.futures

"""
This allows for multiple cores to be used in a single python script. By default, python uses one core.
In general, multiprocessing is less useful if we are using APT on multiple pulsars at once. For example,
if we are solving 20 pulsars and have 20 available cores, then each python script using 1 core each would
yield the best time efficiency anyway.
"""


def fib(n):
    if n == 0 or n == 1:
        return n
    else:
        return fib(n - 2) + fib(n - 1)


start = time.perf_counter()

numbers = [39, 39, 39, 39, 39, 39]

process1 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[0])
process2 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[1])
process3 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[2])
process4 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[3])
process5 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[4])
process6 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[5])

processes = [process1, process2, process3, process4, process5, process6]

time.sleep(
    2
)  # this does not slow down this cell if the runtime without sleeping is >~2 seconds
# Thus, submit() runs the function

print(f"1 after {round(time.perf_counter() - start, 4)} seconds", end="\n\n")

for i, process in enumerate(processes):
    print(
        f"{process.result()}"
    )  # Calling result means the cell must wait until that process is finished, but by
    # no means does this stop any process
    print(
        f"1.5 after {round(time.perf_counter() - start, 4)} seconds : fib number = {numbers[i]}",
        end="\n\n",
    )

print(f"2 after {round(time.perf_counter() - start, 4)}", end="\n\n")

print(f"took {round(time.perf_counter() - start, 4)} seconds")
# Out:
# 1 after 2.0686 seconds
#
# 24157817
# 1.5 after 8.9925 seconds : fib number = 37
#
# 9227465
# 1.5 after 8.9926 seconds : fib number = 35
#
# 39088169
# 1.5 after 14.2308 seconds : fib number = 38
#
# 63245986
# 1.5 after 23.2519 seconds : fib number = 39
#
# 2 after 23.2524
#
# took 23.2526 seconds

# %%
start = time.perf_counter()

print(fib(35))

end = time.perf_counter()

print(f"took {end - start} seconds")
# Out:
# 9227465
# took 3.3230840787291527 seconds

# %%
start = time.perf_counter()

numbers = [33, 35, 33]
numbers_sorted = numbers.copy()
numbers_sorted.sort()

process1 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[0])
process2 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[1])
process3 = concurrent.futures.ProcessPoolExecutor().submit(fib, numbers[2])

processes = [process1, process2, process3]

j = 0
for i in concurrent.futures.as_completed(processes):
    print(
        f"fib number {numbers_sorted[j]} is {i.result()} (took {round(time.perf_counter() - start, 4)} seconds)"
    )
    # This assumes we know which number will be computed faster a priori
    j += 1
# Out:
# fib number 33 is 3524578 (took 1.3535 seconds)
# fib number 33 is 3524578 (took 1.4521 seconds)
# fib number 35 is 9227465 (took 3.3645 seconds)

# %%
def test():
    t = {"h": 4, "t": 5}
    return 1, 4, 5, t


x, y, z, pars = test()
pars.values()
# Out:
# dict_values([4, 5])

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
PATH = "/usr/local/src/miniconda3/envs/presto/bin:/usr/local/src/miniconda3/condabin:/usr/local/src/presto/bin:/users/jdtaylor/bin:/usr/local/src/fv5.4:/usr/local/openmpi-4.1.0/bin:/usr/local/bin:/usr/local/sbin:/usr/local/.cargo/bin:/opt/rh/httpd24/root/usr/bin:/opt/rh/httpd24/root/usr/sbin:/opt/rh/rh-git29/root/usr/bin:/opt/rh/devtoolset-8/root/usr/bin:/usr/local/src/presto/bin:/users/jdtaylor/bin:/usr/local/src/fv5.4:/usr/local/openmpi-4.1.0/bin:/usr/local/bin:/usr/local/sbin:/usr/lib64/qt-3.3/bin:/usr/local/bin:/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/sbin:/opt/local/bin:/users/jdtaylor/bin:/opt/local/bin:/opt/local/bin"

# %%
for path in PATH.split(":"):
    if "/users/jdtaylor" in path:
        print(path)
# Out:
# /users/jdtaylor/bin
# /users/jdtaylor/bin
# /users/jdtaylor/bin

# %%
dict1 = {1: "g", "l": 4}
print(dict1.setdefault(7, "p"))
print(dict1)
# Out:
# p
# {1: 'g', 'l': 4, 7: 'p'}

# %%
import time

x = range(int(2e3))

t1 = time.perf_counter()
for i in x:
    pass
t2 = time.perf_counter()

for i in x:
    for j in x:
        pass
t3 = time.perf_counter()

print(f"one for loop = {t2-t1}seconds.\n" + f"nested = {t3-t2} seconds")
# Out:
# one for loop = 0.00037434324622154236seconds.
# nested = 0.13907581195235252 seconds

# %%
if os.listdir():
    print("hi")
# Out:
# hi

# %%
os.listdir()
# Out:
# ['.git',
#  'simdata_binaryextension.py',
#  'README.md',
#  'simdata.py',
#  'APTchecker.py',
#  'APT',
#  'test5.py',
#  '.ipynb_checkpoints',
#  'test1.py',
#  'test2.ipynb',
#  'test3.py',
#  'test4.py',
#  'APTlargescale.sh',
#  'simdatalargescale.sh']

# %%
for i in {}:
    print("hi")

# %%
def test(a, b, c):
    print(a)
    print(a + c)


def test1(*args):
    return test(*args)


test1(4, 5, 6)
# Out:
# 4
# 10

# %%
t, w, r = [1, 2, 3]

# %%
t
# Out:
# 1

# %%
"fake_9000sol.par"[5:][:-7]
# Out:
# '9000'

# %%
value = 9
f"{value:02f}"
# Out:
# '9.000000'

# %%
import numpy as np

os.chdir("/users/jdtaylor/Jackson/")
with open("atnf.txt") as file:
    contents = file.read().split("\n")
ell1_lines = []
for line in contents:
    if "ELL1" in line:
        if "*" not in line:
            if float(line.split(";")[3]) > 70:
                continue
            ell1_lines.append(line)

# %%
pb = np.zeros(len(ell1_lines))
a1 = np.zeros(len(ell1_lines))
tasc = np.zeros(len(ell1_lines))
eps1 = np.zeros(len(ell1_lines))
eps2 = np.zeros(len(ell1_lines))
values = [pb, a1, tasc, eps1, eps2]
for i, line in enumerate(ell1_lines):
    # print(line)
    split = line.split(";")
    j = 2
    for value in values:
        value[i] = split[j]
        j += 1

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit

##
cutoff = 0.2
z1 = np.where(a1 > cutoff)
z2 = np.where(a1 <= cutoff)


def power_law(x, b, c, d):
    return x**b  # + 10 **c


initial_parameters = [1, 0.001, 0.1]
finalParameters, parCov = curve_fit(power_law, a1[z1], pb[z1], p0=initial_parameters)
b, c, d = finalParameters
a1_synth = np.linspace(cutoff, max(a1), 1000)
pb_synth = power_law(a1_synth, b, c, d)
print(f"final pars are {finalParameters}")

initial_parameters = [1, 0.001, 0.1]
finalParameters, parCov = curve_fit(power_law, a1[z2], pb[z2], p0=initial_parameters)
b, c, d = finalParameters
a1_synth2 = np.linspace(min(a1), cutoff, 1000)
pb_synth2 = power_law(a1_synth2, b, c, d)
print(f"final pars are {finalParameters}")
##

fig, ax = plt.subplots(1, 3, figsize=(25, 10))

(p1,) = ax[0].plot(a1, pb, "o")
(p2,) = ax[0].plot(a1_synth, pb_synth)
(p3,) = ax[0].plot(a1_synth2, pb_synth2)

ax[0].set_xlabel("log(asini (ls))")
ax[0].set_ylabel("log(binary period (days))")

ax[0].set_xscale("log")
ax[0].set_yscale("log")

ax[1].hist(np.log10(pb), bins=20)
ax[1].set_title("Histogram of binary period with log axis")
ax[1].set_xlabel("log(pb (days))")

ax[2].hist(np.log10(a1), bins=20)
# ax[2].plot(np.linspace(0,1, 1000), np.sin(np.linspace(0,1, 1000)))
ax[2].set_title("Histogram of asini with log axis")
ax[2].set_xlabel("log(asini (ls))")

ax[0].grid()
# Out:
# /data1/miniconda3/envs/presto/lib/python3.10/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# final pars are [1.2426958e+00 1.0000000e-03 1.0000000e-01]
# final pars are [0.51258159 0.001      0.1       ]

# %%
plt.plot(np.log10(a1), np.log10(pb), "o")
np.log10(max(a1))
# Out:
# 1.6103353852669102

# %%
import os

def JUMP_adder(timfile, skip_lines=2):
    with open(timfile) as file:
        contents = file.read().split("\n")

    mjd = []
    for i, line in enumerate(contents):
        if line == "" or line[0] == "C" or line[0] == "#":
            continue
        # print(line)
        try:
            mjd.append(float(line.split()[2]))
        except IndexError:
            pass

    first_obs = True
    i = 0
    with open(f"{timfile}JUMP", "w") as file:
        for linenumber, line in enumerate(contents):
            # print(i)
            # print(line)
            # print(f"i is {i}")
            if (
                line == ""
                or line[0] == "C"
                or line[0] == "#"
                or linenumber < skip_lines
            ):
                file.write(line)
            elif mjd[i] - mjd[i - 1] > 0.3 and i > 2:
                # print(line)
                # print(i)
                # print(mjd[i] - mjd[i-1], end = "\n\n")
                i += 1
                if first_obs:
                    file.write("\nJUMP\n")
                    first_obs = False
                else:
                    file.write("JUMP\n\nJUMP\n")
                file.write(line)
            else:
                i += 1
                file.write(line)
            file.write("\n")
        file.write("JUMP\n")

os.chdir("/users/jdtaylor/Jackson/binary1_62/")
JUMP_adder("fake_62.tim")

# %%
#!/usr/bin/env python
import pint.toa
import pint.models
import pint.utils
import os
import numpy.random as r
import numpy as np
import astropy.units as u
from copy import deepcopy
import socket
from astropy.time import TimeDelta
import sys
import pint.logging
from loguru import logger as log
from pathlib import Path
from simdata_binaryextension import binary_pars_setter
from simdata_binaryextension import binary_blur


log.remove()
log.add(
    sys.stderr,
    level="WARNING",
    colorize=True,
    format=pint.logging.format,
    filter=pint.logging.LogFilter(),
)

import pint.fitter
import pint.simulation
import pint.residuals


def zima(
    parfile,
    timfile,
    inputtim: str = None,
    startMJD: float = 56000.0,
    ntoa: int = 100,
    duration: float = 400.0,
    obs: str = "GBT",
    freq: float = 1400.0,
    error: float = 1.0,
    addnoise: bool = False,
    fuzzdays: float = 0.0,
    plot: bool = False,
    format: str = "TEMPO2",
    loglevel: str = pint.logging.script_level,
    mask=None,
):
    log.remove()
    log.add(
        sys.stderr,
        level=loglevel,
        colorize=True,
        format=pint.logging.format,
        filter=pint.logging.LogFilter(),
    )
    global ts
    mask = np.zeros(ntoa, dtype=bool)
    for i in range(len(mask)):
        if i % 10 == 0:
            mask[i] = ~mask[i]

    log.info(f"Reading model from {parfile}")
    m = pint.models.get_model(parfile)

    out_format = format
    error = error * u.microsecond

    if inputtim is None:
        log.info("Generating uniformly spaced TOAs")
        ts = pint.simulation.make_fake_toas_uniform(
            startMJD=startMJD,
            endMJD=startMJD + duration,
            ntoas=ntoa,
            model=m,
            obs=obs,
            error=error,
            freq=np.atleast_1d(freq) * u.MHz,
            fuzz=fuzzdays * u.d,
            add_noise=addnoise,
        )
    else:
        log.info(f"Reading initial TOAs from {inputtim}")
        ts = pint.simulation.make_fake_toas_fromtim(
            inputtim,
            model=m,
            obs=obs,
            error=error,
            freq=np.atleast_1d(freq) * u.MHz,
            fuzz=fuzzdays * u.d,
            add_noise=addnoise,
        )

    # Write TOAs to a file
    # ts.write_TOA_file(f"before{timfile}", name="fake", format=out_format)
    # print(ts.table)
    ts.table = ts.table[mask].group_by("obs")
    ts.table["clusters"] = ts.get_clusters()
    ts.write_TOA_file(f"after{timfile}", name="fake", format=out_format)

    if plot:
        # This should be a very boring plot with all residuals flat at 0.0!
        import matplotlib.pyplot as plt
        from astropy.visualization import quantity_support

        quantity_support()

        r = pint.residuals.Residuals(ts, m)
        plt.errorbar(
            ts.get_mjds(),
            r.calc_time_resids(calctype="taylor").to(u.us),
            yerr=ts.get_errors().to(u.us),
            fmt=".",
        )
        plt.xlabel("MJD")
        plt.ylabel("Residual (us)")
        plt.grid(True)
        plt.show()


os.chdir("/users/jdtaylor/Jackson/APT")
zima("fake_35sol.par", "fake_35.tim")
# Out:
# WARNING  (pint.toa                      ): No ephemeris provided to TOAs object or compute_TDBs. Using DE421

# %%
line = "fake 1400.000000 56363.6363641274648612 1.000 gbt  -pn 306626778.0"
line = line[: line.index("-pn")]
print(line)
# Out:
# fake 1400.000000 56363.6363641274648612 1.000 gbt

# %%
line.index("-pn")
# Out:
# 51

# %%
type(np.array([5]))
# Out:
# numpy.ndarray

# %%
from pint.JTtest import test1

test1()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_40730/1129911596.py in <module>
# ----> 1 from pint.JTtest import test1
#       2 test1()
#
# ImportError: cannot import name 'test1' from 'pint.JTtest' (/users/jdtaylor/Jackson/PINT/src/pint/JTtest.py)

# %%
import numpy as np

z = np.zeros(100, dtype=bool)
np.zeros(100)[z]
# Out:
# array([], dtype=float64)

# %%
from simdata import write_parfile
from simdata_binaryextension import binary_blur
class info:
    def __init__(self):
        self.dblur = None
        self.rblur = None
        self.f1blur = None
        self.f0blur = None
        self.f0blur_range=(0.05,0.15)
        self.PEPOCH=56000
        self.TZRMJD=56000
        self.TZRFRQ=1400
        self.TZRSITE="GBT"
        self.binary_model="ELL1"
        self.binary_blur=None

os.chdir("/users/jdtaylor/Jackson")
args = info()
bp = binary_blur("ell1", (1.619232513, 0), (-0.0000055769, 0), (-0.0000450472, 0), (0.38547212270906, 0), (53203.686011086, 0))
write_parfile(args, "ter5edited.par", h=17,m=48,s=4.91929122,
 d=-24, arcm=46, arcs=53.7307104, f0=(115.3814657387290197, 1e-10), f1=(-7.367186348571e-15, 0), dm=(238.328540, 0), ntoa2=5, density=0.008, binary_pars=bp)

# %%
from pathlib import Path
import pint
def cluster_phase_checker(m, t):
    """
    Checks whether a cluster is phased wrapped and organizes TOAs wihtin a cluster into those already phase connected.
    model: model object
    model: path to par file OR models object
    toa: path to tim file OR TOA object
    """
    if type(t) != pint.toa.TOAs:
        t = pint.toa.get_TOAs(t)
    if type(m) != pint.models.timing_model.TimingModel:
        pint.models.get_model(m)

# %%
def test(s):
    return 0
test(5,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_89408/3503166485.py in <module>
#       1 def test(s):
#       2     return 0
# ----> 3 test(5,5)
#
# TypeError: test() takes 1 positional argument but 2 were given

# %%
import pint.toa
import pint.models
import pint.fitter
import pint.residuals
import pint.utils
import pint.models.model_builder as mb
import pint.random_models
from pint.phase import Phase
from copy import deepcopy
from collections import OrderedDict
from astropy import log
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import operator
import time
from pathlib import Path

os.chdir(Path("/Users/jackson/Desktop/Pint_Personal/APT/binary1_62/"))
timfile = "fake_62.tim"

parfile = "1.par"
m, toas = mb.get_model_and_toas(parfile, timfile)


toas.table["clusters"] = toas.get_clusters()
print(m.as_parfile(), end = "\n\n\n")

t = deepcopy(toas)
mjd_values = t.get_mjds().value
dts = np.fabs(mjd_values - mjd_values[:, np.newaxis]) + np.eye(len(mjd_values))

score_list = list((1.0 / dts).sum(axis=1))

# f = pint.fitter.WLSFitter(t, m)
# f.fit_toas()
for j in range(5):
    print(max(score_list), hsi := np.argmax(score_list), mjd_values[hsi], t.table["clusters"][hsi])
    #hsi = np.argmax(score_list)
    score_list[hsi] = 0

#t.write_TOA_file("mac.tim")
# Out:
# 2022-06-22 14:56:16.253 | DEBUG    | pint.toa:get_TOAs:190 - Using EPHEM = DE421 from the given model
# 2022-06-22 14:56:16.255 | DEBUG    | pint.toa:get_TOAs:206 - Using CLOCK = BIPM2019 from the given model
# 2022-06-22 14:56:16.501 | DEBUG    | pint.toa:__init__:1304 - No pulse number flags found in the TOAs
# 2022-06-22 14:56:16.504 | DEBUG    | pint.toa:apply_clock_corrections:2085 - Applying clock corrections (include_gps = True, include_bipm = True)
# 2022-06-22 14:56:16.518 | INFO     | pint.observatory.global_clock_corrections:get_file:121 - File index.txt to be downloaded due to download policy if_expired: https://raw.githubusercontent.com/ipta/pulsar-clock-corrections/main/index.txt
# 2022-06-22 14:56:16.599 | DEBUG    | pint.observatory.clock_file:__init__:566 - Loading tempo observatory (None) clock correction file /Users/jackson/.astropy/cache/download/url/599e3ebbfc317e090244ee1ef4c79374/contents
# ...

# %%
os.chdir("/users/jackson/Desktop/Pint_Personal/APT/binar3_1/")
m, toas = mb.get_model_and_toas("fake_1.par", "fake_1.tim")
#def starting_points(toas, args = None):
t = deepcopy(toas)
t.table["clusters"] = t.get_clusters()
mjd_values = t.get_mjds().value
dts = np.fabs(mjd_values - mjd_values[:, np.newaxis]) + np.eye(len(mjd_values))

score_list = (1.0 / dts).sum(axis=1)

mask_list = []
starting_cluster_list = []
# f = pint.fitter.WLSFitter(t, m)
# f.fit_toas()
i = -1
while score_list.any():
    #break
    i += 1
    #print(i)
    hsi = np.argmax(score_list)
    score_list[hsi] = 0
    cluster = t.table["clusters"][hsi]
    #mask = np.zeros(len(mjd_values), dtype=bool)
    mask = t.table["clusters"] == cluster

    if i == 0 or not np.any(np.all(mask == mask_list, axis=1)): #equivalent to the intended effect of checking if not mask in mask_list
        mask_list.append(mask)
        starting_cluster_list.append(cluster)

mask = mask_list[1]
#mask[7:10] = 1
#def JUMP_adder(mask):
former_clusters = -1 * np.ones(len(t.table))
former_clusters[mask] = t.table[mask]["clusters"]
#available_jump_names = t.table[~mask]["clusters"] # this works only if mask applies to a whole number of clusters
j = 0
for i, table in enumerate(t.table[~mask]):
    # if table["clusters"] not in former_clusters:
    #     print(table["clusters"], end = ", ")
    #     former_clusters[~mask][i] = table["clusters"]
    #     j += 1
    table["flags"]["jump_tim"] = str(available_jump_names[i])#str(table["clusters"] + 1)#str(j)


t.write_TOA_file("mac.tim")
# Out:
# 2022-06-22 15:14:42.777 | DEBUG    | pint.toa:__init__:1304 - No pulse number flags found in the TOAs
# 2022-06-22 15:14:42.779 | DEBUG    | pint.toa:apply_clock_corrections:2085 - Applying clock corrections (include_gps = True, include_bipm = True)
# 2022-06-22 15:14:42.794 | INFO     | pint.observatory.topo_obs:clock_corrections:258 - Applying observatory clock corrections.
# 2022-06-22 15:14:42.796 | INFO     | pint.observatory.topo_obs:clock_corrections:263 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2022-06-22 15:14:42.797 | INFO     | pint.observatory.topo_obs:clock_corrections:268 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2022-06-22 15:14:42.896 | DEBUG    | pint.toa:compute_TDBs:2148 - Computing TDB columns.
# 2022-06-22 15:14:42.897 | WARNING  | pint.toa:compute_TDBs:2160 - No ephemeris provided to TOAs object or compute_TDBs. Using DE421
# ...

# %%
mask[8:10]
# Out:
# array([ True,  True])

# %%
for i, table in enumerate(t.table[~mask]):
    #print(i)
    print(table["clusters"] in )
    break
# Out:
#   Input In [52]
#     print(table["clusters"] in )
#                                ^
# SyntaxError: invalid syntax

# %%
m, t = mb.get_model_and_toas("errorpar.par", "fake_62.timJUMP")
f = pint.fitter.WLSFitter(t, m)
#f.get_designmatrix()
f.fit_toas()
print(f.model.F0.value - m.F0.value)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb Cell 87' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb#ch0000084?line=0'>1</a> m, t = mb.get_model_and_toas("errorpar.par", "fake_62.timJUMP")
#       <a href='vscode-notebook-cell:/Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb#ch0000084?line=1'>2</a> f = pint.fitter.WLSFitter(t, m)
#       <a href='vscode-notebook-cell:/Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb#ch0000084?line=2'>3</a> f.fit_toas()
#
# File ~/Desktop/Pint_Personal/PINT/src/pint/models/model_builder.py:638, in get_model_and_toas(parfile, timfile, ephem, include_bipm, bipm_version, include_gps, planets, usepickle, tdb_method, picklefilename, allow_name_mixing)
#     585 def get_model_and_toas(
# ...

# %%
former_cluster = t.table[mask]["clusters"][0]
former_cluster
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb#ch0000000?line=0'>1</a> former_cluster = t.table[mask]["clusters"][0]
#       <a href='vscode-notebook-cell:/Users/jackson/Desktop/Pint_Personal/APT/APTJunk/test2.ipynb#ch0000000?line=1'>2</a> former_cluster
#
# NameError: name 'mask' is not defined

# %%
x = np.array([0,2,3], dtype=bool)
y = [x, np.array([2,3,4,0,23], dtype=bool)]
x in y
# Out:
# True

# %%
y = pint.residuals.Residuals(t, f.model).phase_resids.value
fig, ax = plt.subplots(figsize = (15,10))
ax.plot(mjd_values, y, 'o')
ax.set_xticks(np.arange(56000, 56300, 20))
plt.grid()

# %%
# Out:
# array([ 0.05209747,  0.04967885,  0.04147833,  0.04108336,  0.03925253,
#         0.04158658,  0.0349307 ,  0.04095075,  0.27112656,  0.39063856,
#         0.37995877,  0.38272509,  0.37900193,  0.28215264,  0.286028  ,
#         0.28497996,  0.29424931, -0.24769235, -0.24099376, -0.25144738,
#        -0.25145514, -0.25619967, -0.26148609, -0.25585597, -0.05383817,
#        -0.06784665, -0.06645346, -0.07181844, -0.07054093, -0.08189007,
#        -0.08703113,  0.34693416, -0.33661542, -0.31742785, -0.31175676,
#        -0.31123347, -0.30399532, -0.30290031, -0.302026  , -0.20058389,
#        -0.20505458, -0.19666934,  0.07338268,  0.01001319, -0.08363982,
#        -0.07995135, -0.07414123, -0.06352164,  0.35198333,  0.35443107,
#         0.35443559,  0.34794611,  0.35035163,  0.35300729,  0.46073288,
#         0.44581774,  0.44471981,  0.4485639 , -0.38820896, -0.39578063,
#        -0.40489211, -0.4126203 , -0.41187378, -0.07770667, -0.07656031,
# ...

# %%
# Out:
# hi
